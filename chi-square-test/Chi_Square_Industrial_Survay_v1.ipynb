# %% [markdown]
# <a href="https://colab.research.google.com/github/vrundag91/industrial-survey-for-recruitment-process/blob/main/chi-square-test/Chi_Square_Industrial_Survay_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sample Example

# %%
import numpy as np
import scipy.stats as stats

# Data
observed = np.array([[25, 40], [60, 70], [20, 30]])

# Perform the Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(observed)

# Interpret the test results
alpha = 0.05
if p < alpha:
    print(f"Reject H0. There is a relationship between gender and preference of operating system (p = {p:.4f})")
else:
    print(f"Fail to reject H0. There is no relationship between gender and preference of operating system (p = {p:.4f})")
# Out:
# Fail to reject H0. There is no relationship between gender and preference of operating system (p = 0.5335)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Data
observed = np.array([[25, 40], [60, 70], [20, 30]])

# Perform the Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(observed)

# Plot the critical region
x = np.linspace(0, 20, 1000)
y = stats.chi2.pdf(x, dof)
critical_value = stats.chi2.ppf(0.95, dof)

print("chi2 = ", chi2)
print("p = ", p)
print("dof = ", dof)
print("expected = ", expected)

print("critical_value = ", critical_value)


plt.plot(x, y, label='Chi-square distribution')
plt.axvline(critical_value, color='red', linestyle='--', label='Critical value (alpha = 0.05)')
plt.axvline(chi2, color='green', linestyle='--', label='Test statistic')
plt.legend()
plt.xlabel('Chi-square')
plt.ylabel('Probability density')
plt.title(f'Chi-square test (dof = {dof})')
plt.show()
# Out:
# chi2 =  1.2564102564102562
# p =  0.5335485934116908
# dof =  2
# expected =  [[27.85714286 37.14285714]
#  [55.71428571 74.28571429]
#  [21.42857143 28.57142857]]
# critical_value =  5.991464547107979

# %% [markdown]
# # Industry Survey data

# %% [markdown]
# ### Company_size v/s responses

# %%
import csv
import pandas as pd
from collections import defaultdict

# Load data from the CSV file
data = []
with open('/content/company_size_vs_response.csv', 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        data.append(row)

# Create a frequency table
frequency_table = defaultdict(lambda: defaultdict(int))
for row in data:
    company_size = row['company_size']
    response = row['response']
    frequency_table[company_size][response] += 1

# Convert the frequency table to a DataFrame
df = pd.DataFrame(frequency_table)
df = df.fillna(0).astype(int)
df = df.T  # Transpose the DataFrame so that company_size becomes the index

# Add row and column totals to the DataFrame
df['rTOTAL'] = df.sum(axis=1)
df.loc['cTOTAL'] = df.sum(axis=0)

# Print the DataFrame
print(df)
# Out:
#         yes  try  no  rTOTAL
# medium   18   20   2      40
# small     6   10   9      25
# large    37   11   6      54
# micro     2    3   2       7
# cTOTAL   63   44  19     126

# %%
# Data
observed = np.array([[18, 20, 2], [6, 10, 9], [37, 11, 6], [2, 3, 2]])

# Perform the Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(observed)

# Interpret the test results
alpha = 0.05
if p < alpha:
    print(f"Reject H0. There is a relationship between company size and response towards our proposed system (p = {p:.4f})")
else:
    print(f"Fail to reject H0. There is no relationship between company size and response towards our proposed system (p = {p:.4f})")
# Out:
# Reject H0. There is a relationship between company size and response towards our proposed system (p = 0.0003)

# %%
# Data
observed = np.array([[18, 20, 2], [6, 10, 9], [37, 11, 6], [2, 3, 2]])

# Perform the Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(observed)

# Plot the critical region
x = np.linspace(0, 20, 1000)
y = stats.chi2.pdf(x, dof)
critical_value = stats.chi2.ppf(0.95, dof)

print("chi2 = ", chi2)
print("p = ", p)
print("dof = ", dof)
print("expected = ", expected)

print("critical_value = ", critical_value)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Chi-square distribution')
plt.axvline(critical_value, color='red', linestyle='--', label='Critical value (alpha = 0.05)')
plt.axvline(chi2, color='green', linestyle='--', label='Test statistic')
plt.legend()
plt.xlabel('Chi-square')
plt.ylabel('Probability density')
plt.title(f'Chi-square test (dof = {dof})')
plt.show()
# Out:
# chi2 =  25.475954785954787
# p =  0.0002786617428259854
# dof =  6
# expected =  [[20.         13.96825397  6.03174603]
#  [12.5         8.73015873  3.76984127]
#  [27.         18.85714286  8.14285714]
#  [ 3.5         2.44444444  1.05555556]]
# critical_value =  12.591587243743977

# %% [markdown]
# ### sector v/s response

# %%
import csv
import pandas as pd
from collections import defaultdict

# Load data from the CSV file
data = []
with open('/content/sectors_vs_response.csv', 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        data.append(row)

# Create a frequency table
frequency_table = defaultdict(lambda: defaultdict(int))
for row in data:
    sector = row['sector']
    response = row['response']
    frequency_table[sector][response] += 1

# Convert the frequency table to a DataFrame
df = pd.DataFrame(frequency_table)
df = df.fillna(0).astype(int)
df = df.T  # Transpose the DataFrame so that company_size becomes the index

# Add row and column totals to the DataFrame
df['rTOTAL'] = df.sum(axis=1)
df.loc['cTOTAL'] = df.sum(axis=0)

# Print the DataFrame
print(df)
# Out:
#            yes  try  no  rTOTAL
# education   12   12   2      26
# finance     16    7   2      25
# IT          10   11   2      23
# legal       15    6   5      26
# other       10    8   8      26
# cTOTAL      63   44  19     126

# %%
# Data
observed = np.array([[12, 12, 2], [16, 7, 2], [10, 11, 2], [15, 6, 5], [10, 8, 8]])

# Perform the Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(observed)

# Interpret the test results
alpha = 0.05
if p < alpha:
    print(f"Reject H0. There is a relationship between sector and response towards our proposed system (p = {p:.4f})")
else:
    print(f"Fail to reject H0. There is no relationship between sector and response towards our proposed system (p = {p:.4f})")
# Out:
# Fail to reject H0. There is no relationship between sector and response towards our proposed system (p = 0.1211)

# %%
# Data
observed = np.array([[12, 12, 2], [16, 7, 2], [10, 11, 2], [15, 6, 5], [10, 8, 8]])

# Perform the Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(observed)

# Plot the critical region
x = np.linspace(0, 20, 1000)
y = stats.chi2.pdf(x, dof)
critical_value = stats.chi2.ppf(0.95, dof)

print("chi2 = ", chi2)
print("p = ", p)
print("dof = ", dof)
print("expected = ", expected)

print("critical_value = ", critical_value)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Chi-square distribution')
plt.axvline(critical_value, color='red', linestyle='--', label='Critical value (alpha = 0.05)')
plt.axvline(chi2, color='green', linestyle='--', label='Test statistic')
plt.legend()
plt.xlabel('Chi-square')
plt.ylabel('Probability density')
plt.title(f'Chi-square test (dof = {dof})')
plt.show()
# Out:
# chi2 =  12.739664271655117
# p =  0.12112640295673942
# dof =  8
# expected =  [[13.          9.07936508  3.92063492]
#  [12.5         8.73015873  3.76984127]
#  [11.5         8.03174603  3.46825397]
#  [13.          9.07936508  3.92063492]
#  [13.          9.07936508  3.92063492]]
# critical_value =  15.50731305586545
